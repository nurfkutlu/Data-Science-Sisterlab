# %%
import matplotlib.pyplot as plt
import matplotlib.colors as mcolors #https://matplotlib.org/stable/gallery/color/named_colors.html
import matplotlib.patches as mpatches
import numpy as np
import pandas as pd
import seaborn as sns

# %%
df=pd.read_csv('C:/Users/Hp/Desktop/SistersLab/Data-Science-Sisterlab/Data-Science-Sisterlab/Exercises/Class/Data/birds.csv')

# %%
df.head()
# Out:
#                            Name          ScientificName  \
# 0  Black-bellied whistling-duck  Dendrocygna autumnalis
# 1        Fulvous whistling-duck     Dendrocygna bicolor
# 2                    Snow goose      Anser caerulescens
# 3                  Ross's goose            Anser rossii
# 4   Greater white-fronted goose         Anser albifrons
#
#                 Category         Order    Family        Genus  \
# 0  Ducks/Geese/Waterfowl  Anseriformes  Anatidae  Dendrocygna
# 1  Ducks/Geese/Waterfowl  Anseriformes  Anatidae  Dendrocygna
# 2  Ducks/Geese/Waterfowl  Anseriformes  Anatidae        Anser
# 3  Ducks/Geese/Waterfowl  Anseriformes  Anatidae        Anser
# 4  Ducks/Geese/Waterfowl  Anseriformes  Anatidae        Anser
#
#   ConservationStatus  MinLength  MaxLength  MinBodyMass  MaxBodyMass  \
# 0                 LC       47.0       56.0        652.0       1020.0
# 1                 LC       45.0       53.0        712.0       1050.0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 443 entries, 0 to 442
# Data columns (total 13 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Name                443 non-null    object
#  1   ScientificName      443 non-null    object
#  2   Category            443 non-null    object
#  3   Order               443 non-null    object
#  4   Family              443 non-null    object
#  5   Genus               443 non-null    object
#  6   ConservationStatus  443 non-null    object
#  7   MinLength           443 non-null    float64
#  8   MaxLength           443 non-null    float64
#  9   MinBodyMass         443 non-null    float64
#  10  MaxBodyMass         443 non-null    float64
#  11  MinWingspan         443 non-null    float64
#  12  MaxWingspan         443 non-null    float64
# dtypes: float64(6), object(7)
# memory usage: 45.1+ KB

# %%
df.describe()
# Out:
#         MinLength   MaxLength  MinBodyMass   MaxBodyMass  MinWingspan  \
# count  443.000000  443.000000   443.000000    443.000000   443.000000
# mean    28.536682   35.441986   327.938262    667.009752    58.557901
# std     20.319887   27.539772   779.680106   1655.682564   104.602369
# min      7.000000    8.900000     2.000000      3.000000     8.000000
# 25%     13.750000   16.000000    18.000000     28.000000    23.000000
# 50%     20.500000   25.000000    55.000000     89.000000    38.000000
# 75%     39.000000   46.000000   332.000000    593.000000    72.750000
# max    138.000000  180.000000  9200.000000  14300.000000  1800.000000
#
#        MaxWingspan
# count   443.000000
# mean     67.524492
# std     126.673177
# min      10.600000
# 25%      25.000000
# 50%      42.000000
# 75%      83.000000
# max    2300.000000

# %%
categoric_col=['Category',
    'Order',
    'Family',
    'Genus',
    'ConservationStatus'

]

# %% [markdown]
# Group By

# %%
"""  
A groupby operation involves some combination of splitting the **object**, applying a function, and combining the results. 
This can be used to group large amounts of data and compute operations on these groups."""
# sorted_counts = grouped_counts.sort_values(ascending=False)
#groupby("ben neyi filtrelemek istiyorum?")["positonal argument ne"]....
Cat_gr=df.groupby("Category")['Name'].count().sort_values(ascending=False)
print(Cat_gr)

plt.figure(figsize=(15, 6))
plt.xticks(rotation=45, ha='right')
sns.barplot(x = Cat_gr.index, y = Cat_gr.values)
plt.show()
# Out:
# Category
# Ducks/Geese/Waterfowl              45
# New World warblers                 41
# Sandpipers/Allies                  34
# Gulls/Terns/Skimmers               28
# New World sparrows                 26
# Tyrant flycatchers                 19
# Hawks/Eagles                       15
# Troupials/Allies                   14
# Finches/Euphonias/Allies           13
# Woodpeckers                        12
# Herons/Egrets/Bitterns             11
# Cardinals/Allies                   11
# Thrushes/Allies                    11
# Owls                               11
# Pheasants/Grouse/Allies             9
# Pigeons/Doves                       8
# Rails/Gallinules/Coots              8
# Vireos/Shrike-babblers/Erpornis     7
# Hummingbirds                        7
# Swallows                            7
# Plovers/Lapwings                    7
# Wrens                               7
# Grebes                              6
# Falcons /Caracaras                  6
# ...

# %%
Fam_gr=df.groupby("Family")['Name'].count().sort_values(ascending=False)
print(Fam_gr)

#Plot
plt.figure(figsize=(15, 6))
plt.xticks(rotation=45, ha='right')
sns.barplot(x = Fam_gr.index, y = Fam_gr.values)
plt.show()
# Out:
# Family
# Anatidae             45
# Parulidae            41
# Scolopacidae         34
# Laridae              28
# Passerellidae        26
# Tyrannidae           19
# Accipitridae         15
# Icteridae            15
# Fringillidae         13
# Picidae              12
# Cardinalidae         11
# Strigidae            11
# Ardeidae             11
# Turdidae             11
# Phasianidae           9
# Rallidae              8
# Columbidae            8
# Trochilidae           7
# Troglodytidae         7
# Hirundinidae          7
# Vireonidae            7
# Charadriidae          7
# Falconidae            6
# Podicipedidae         6
# Corvidae              6
# Calcariidae           5
# Mimidae               5
# Threskiornithidae     4
# Caprimulgidae         4
# Gaviidae              4
# Alcidae               4
# Paridae               3
# Stercorariidae        3
# Sittidae              3
# Cuculidae             3
# Bombycillidae         2
# Apodidae              2
# Passeridae            2
# ...

# %%
group_family=df.groupby(["Category","Family"])["MinBodyMass"].min().sort_values(ascending=False)
print(group_family)
# Out:
# Category                         Family
# Cranes                           Gruidae              4020.0
# Storks                           Ciconiidae           2000.0
# Pelicans                         Pelecanidae          2000.0
# Frigatebirds                     Fregatidae           1100.0
# Cormorants/Shags                 Phalacrocoracidae    1000.0
# Loons                            Gaviidae             1000.0
# Osprey                           Pandionidae           900.0
# New World vultures               Cathartidae           800.0
# Ibises/Spoonbills                Threskiornithidae     450.0
# Shearwaters and petrels          Procellariidae        450.0
# Pheasants/Grouse/Allies          Phasianidae           385.0
# Grebes                           Podicipedidae         253.0
# Skuas and jaegers                Stercorariidae        230.0
# Barn-owls                        Tytonidae             224.0
# Stilts and avocets               Recurvirostridae      150.0
# ...

# %%
plt.figure(figsize=(15, 6))

group_family=df.groupby(["Category","Family"])["MinBodyMass"].min().sort_values(ascending=False).plot(legend=True)

plt.show()

# %%
df.groupby("Order")["ConservationStatus"].count().sort_values(ascending = False)
# Out:
# Order
# Passeriformes        195
# Charadriiformes       78
# Anseriformes          45
# Pelecaniformes        17
# Accipitriformes       16
# Strigiformes          12
# Piciformes            12
# Gruiformes            10
# Galliformes           10
# Apodiformes            9
# Columbiformes          8
# Podicipediformes       6
# Falconformes           6
# Gaviiformes            4
# Caprimulgiformes       4
# Cuculiformes           3
# Suliformes             3
# Cathartiformes         2
# Coraciiformes          1
# Ciconiiformes          1
# Procellariiformes      1
# Name: ConservationStatus, dtype: int64

# %%
num_cols=[
    'MinLength','MaxLength', 'MinBodyMass',	'MaxBodyMass',	'MinWingspan',	'MaxWingspan'
]
for num in num_cols:
    sns.histplot(x =df[num], kde=True)
    plt.show()

# %% [markdown]
# Boxplot

# %%
for num in num_cols:
    sns.boxplot(x=df[num],data=df)
    plt.show()

# %% [markdown]
# Density Chart

# %%
# plotting both distibutions on the same figure
fig = sns.kdeplot(df['MinLength'], fill=True, color="r",label='MinLength')
fig = sns.kdeplot(df['MaxLength'],fill=True, color="b",label='MaxLength')
plt.legend(loc='best') # to see legend
plt.show()

# %% [markdown]
# Violin

# %% [markdown]
# A violint plot allows you to visualize the distribution of a numeric variable for one or several groups

# %%
plt.figure(figsize=(15, 6))
plt.xticks(rotation=45, ha='right')
sns.violinplot(x=df["Family"], y=df["MaxLength"])
# Out:
# <Axes: xlabel='Family', ylabel='MaxLength'>

# %% [markdown]
# Correlation

# %% [markdown]
# Scatter Plot

# %% [markdown]
# A scatter plot displays the relationship between 2 numeric variables,

# %%
sns.regplot(x=df["MinWingspan"], y=df["MinBodyMass"],line_kws={"color":"r","alpha":0.7,"lw":5})
plt.show()

# %%
sns.regplot(x=df["MinWingspan"], y=df["MaxWingspan"],line_kws={"color":"r","alpha":0.7,"lw":5})
plt.show()

# %% [markdown]
# Bubble Plot

# %%
sns.scatterplot(data=df, x="MaxLength", y="MinLength", size="MinWingspan", legend=False, sizes=(20, 2000))
# Out:
# <Axes: xlabel='MaxLength', ylabel='MinLength'>

# %%
plt.figure(figsize=(10, 6))
sns.barplot(x='Name', y='MaxWingspan', data=df[:10], color='blue', label='Max BodyMass')
sns.barplot(x='Name', y='MinWingspan', data=df[:10], color='purple', label='Min BodyMass')
plt.xticks(rotation=50, ha='right')
plt.ylabel('BodyMass')
plt.legend()
plt.show()
